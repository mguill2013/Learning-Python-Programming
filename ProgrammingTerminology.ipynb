# %%
# The following program is a collection of simple Python programs that I wrote to learn the basics of Python.
# I am using the Python Programming MOOC 2025 course as a reference and guide. 
# This ipynb file contains objectives from "Introduction to Programming Part 2: Programming Terminology". 


# A statement is a part of the program which executes something. It often, but not always, refers to a single command.
# For example, print("Hi!") is a statement. number = 2 is also a statement.
# A statement can also be more complicated:

if name == "Anna":
    print("Hi!")
    number = 2

# In the above program, there are two statements (a print statement and an assignment statement) within a conditional statement.


# A block is a group of consecutive statements that are at the same level in the strucutre of the program. 
# For example, the block of a conditional statement contains those statements which are executed only if the condition is true. 

if age > 17:
    # beginning of the conditional block
    print("You are of age!")
    age = age + 1
    print("You are now one year older...")
    # end of the conditional block

print("This print statement is outside of the conditional block.")

# In Python, blocks are expressed by indentation of all code in the same block by the same amount of whitespace.
# The main block of a Python program must always be at the leftmost edge of the file, without any indentation.


# An expression is a bit of code that results in a determined data type. 
# When the program is executed, the expression is evaluated so that it has a value that can then be used in the program. 

2 + 4 + 3
# The above expression is evaluated to a value of 9. The type of the expression is an integer. The python data type of the expression is int.

"abc" + "de"
# The above expression is evaluated to a value of "abcde". The type of the expression is a string. The python data type of the expression is str.

11 / 2 
# The above expression is evaluated to a value of 5.5. The type of the expression is a float. The python data type of the expression is float.

2 * 5 > 9 
# The above expression is evaluated to a value of True. The type of the expression is a boolean value. The python data type of the expression is bool.

# Because all expressions have a type, they can be assigned to variables:
x = 1 + 2

# Simple expressions can be assembled together to form more complicated expressions, for example with arithmetic operations:
y = 3 * x + x**2


# A function executes some functionality.
# Functions can also take one or more arguments, which are data that can be fed to and processed by the function. 
# Arguments are also sometimes referred to as parameters.
# A function is exectured when it is "called". That is, when the function (and its arguments, if any) is mentioned in the code. 
# The following statement calls the print function with the argument "this is an argument":

print("this is an argument")

# Another function i've already used often is the input function, which asks the user for input.
# The argument of this functio is the message that is show to the user:

name  input("Please type in your name: ")

# In this case, the function also returns a value. 
# After the function has been executed, the value that was returned is assigned to the variable name.


# Data type refers to the characteristics of any value present in the program.
# In the following bit of code the data type of the variable name is string or str, and the data type of the variable result is integer or int.

name = "Anna"
result = 100

# You can use the function type() to check the data type of a variable.

print(type("Anna")) # This output is str
print(type(100)) # This output is int


# Similarly to natural languages, the syntax of a programming language determines how the code of a program should be written.
# If the syntatic rules of the programming language are not followed, the program will return an error.


# If the syntax of the program is correct but the program still doesn't function as intended, there is a bug in the program.
# Bugs manifest in different ways. Some bugs case an error during execution, while others cause the program to produce incorrect results.

# The following program contains a bug:

x = 10
y = 0
result = x / y

print(f"{x} divided by {y} is {result}")
# The above program will return a ZeroDivisionError because the program is trying to divide by zero.

# I following program contains several bugs and syntax errors::

# Fix the program
  number = input("Please type in a number: ")
  if number>100
    print("The number was greater than one hundred")
    number - 100
    print("Now its value has decreased by one hundred)
      print("Its value is now"+ number)
 print(number + " must be my lucky number!")
 print("Have a nice day!)
       
# I have fixed the program below:

number = int(input("Please type in a number: "))

if number > 100:
    print("The number was greater than one hundred")
    number -= 100
    print("Now its value has decreased by one hundred")
    print(f"Its value is now {number}")

print(f"{number} must be my lucky number!")
print("Have a nice day!")

# The above program will now run without any errors.

# Q: What was wrong with the original program and which fixes were made?
# 1. The first line of the program was indented, which is not correct. The first line of the program should not be indented.
# 2. The second line of the program was missing a colon at the end of the if statement.
# 3. The program was missing a closing quotation mark at the end of several print statements.
# 4. The fourth line of the program was indented too much. The print statement should not be indented.


# The function "len" can be used to find out the length of a string, among other things.
# The function returns the number of characters in a string.
# Some examples of how this works are below:

word = "abcd"
print(len(word)) # Outputs "4"

print(len("hi there")) # Outputs "8"

word2 = "howdydoody"
length = len(word2)
print(length) # Outputs "10"

empty_string = " "
length = len(empty_string)
print(length) # Outputs "0"


# The following program asks the user for a word and then prints out the number of characters, if there was more than one typed in.

word = input("Please type in a word: ")
length = len(word)
print(f"There are {length} letters in the word {word}")
print("Thank you!")

# When programming in Python, often we need to change the data type of a value.
# For example, a floating point number can be converted into an integer with the function int:

temperature = float(input("Please type in a temperature: "))
print("The temperature is", temperature)
print("...and rounded down it is", int(temperature))

# The function always rounds down, and not according to the rounding rules in mathematics. This is an example of a "Floor Function"

# The following program asks the user for a floating point number and then prints out the integer part and the decimal part separately.

number = float(input("Please type in a number: "))
integer_part = int(number)
decimal_part = number - integer_part

print(f"Integer part: {integer_part}")
print(f"Decimal part: {decimal_part}")
